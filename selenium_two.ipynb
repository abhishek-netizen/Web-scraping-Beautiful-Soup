# %%
# load library
import csv
import time
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup

# %%
# chromedriver url link
driver=webdriver.Chrome("./chromedriver")

# %%
# create dictionary
jobs={"roles":[],
     "companies":[],
     "locations":[],
     "experience":[],
     "skills":[],
     "salary":[],
     "job_desc":[]}

# %%
# link of website you want to scrap
for i in range(1):
    driver.get("https://www.naukri.com/data-scientist-jobs-{}".format(i))
    time.sleep(3)
    lst=driver.find_elements_by_css_selector(".jobTuple.bgWhite.br4.mb-8")
    
    # scrape the data from website
    for job in lst:
        driver.implicitly_wait(10)
        role=job.find_element_by_css_selector("a.title.fw500.ellipsis").text
        company=job.find_element_by_css_selector("a.subTitle.ellipsis.fleft").text
        location=job.find_element_by_css_selector(".fleft.grey-text.br2.placeHolderLi.location").text
        exp=job.find_element_by_css_selector(".fleft.grey-text.br2.placeHolderLi.experience").text
        skills=job.find_element_by_css_selector(".tags.has-description").text
        salary=job.find_element_by_css_selector(".fleft.grey-text.br2.placeHolderLi.salary").text
        job_desc=job.find_element_by_css_selector(".job-description.fs12.grey-text").text
        jobs["roles"].append(role)
        jobs["companies"].append(company)
        jobs["locations"].append(location)
        jobs["experience"].append(exp)
        jobs["skills"].append(skills)
        jobs["salary"].append(salary)
        jobs["job_desc"].append(job_desc)

# %%
# tranform data into dataframe
data=pd.DataFrame.from_dict(jobs)
data.head(10)
# Out:
#                                                roles  \
# 0  Data Scientist/Analyst - Machine Learning/Deep...
# 1                   Data Scientist, Machine Learning
# 2                                  Data Scientist, I
# 3           Explore job openings on Data Scientist!!
# 4  Inviting Application For Data Scientist - Mana...
# 5  Senior Principal Software Engineer - IT (Data ...
# 6             Data Scientist/Analyst – IT Department
# 7             Data Scientist/Analyst – IT Department
# 8                   Data Scientist, Machine Learning
# 9  Assistant Manager/ Manager/ Data Scientist - P...
#
#                                           companies                locations  \
# 0                                         EchoIndia                    Delhi
# 1                             Fractal Analytics Ltd                Bengaluru
# 2                              iXplore Technologies                Bengaluru
# 3                         Bristlecone India Limited  Pune, Mumbai, Bengaluru
# 4                     GENPACT India Private Limited                Bengaluru
# 5  Dell International Services IndiaPrivate Limited                Bengaluru
# 6                              Nandan Denim Limited                Ahmedabad
# 7                              Nandan Denim Limited                Ahmedabad
# 8                                        Fractal.ai                Bengaluru
# 9                         Huquo Consulting Pvt. Ltd                Bengaluru
#
#   experience                                             skills  \
# 0    3-6 Yrs  IT Skills\nPython\nMachine Learning\nTableau\n...
# 1    3-7 Yrs  Supply chain management\nLinux\nRF\nRDBMS\nBfs...
# 2    0-2 Yrs  IT Skills\nSoftware Development\nMachine Learn...
# 3    4-9 Yrs  IT Skills\nPython\nData Science\nMachine Learn...
# 4   6-11 Yrs  Machine Learning\nStatistics\nDeep Learning\nR...
# 5  10-12 Yrs  IT Skills\nPython\nTesting\nMachine Learning\n...
# 6    7-8 Yrs  Data Analysis\nStatistical Modeling\nPredictiv...
# 7    7-8 Yrs  Data Analysis\nStatistical Modeling\nPredictiv...
# 8    3-7 Yrs  Supply chain management\nLinux\nRF\nRDBMS\nBfs...
# 9    3-8 Yrs  Data Science\nPredictive Modeling\nNLP\nData S...
#
#                     salary                                           job_desc
# 0            Not disclosed  - Strong experience in statistical models and ...
# 1            Not disclosed  Experience of working on end-to-end data scien...
# 2            Not disclosed  Bachelors degree, Masters or PhD in statistics...
# 3  3,00,000 - 8,00,000 PA.  Hands-on python programming with experience de...
# 4            Not disclosed  With a startup spirit and 90, 000+ curious and...
# 5            Not disclosed  Proficiency in Python or R, Tableu especially ...
# 6            Not disclosed  Hands on experience in one or more databases l...
# 7            Not disclosed  Hands on experience in one or more databases l...
# 8            Not disclosed  Experience of working on end-to-end data scien...
# 9            Not disclosed  Experience in machine learning algorithm devel...

# %%
data.shape
# Out:
# (3000, 7)

# %%
data.to_csv('C:/Users/hp/Desktop/web scrape/second/second.csv',index=True)
